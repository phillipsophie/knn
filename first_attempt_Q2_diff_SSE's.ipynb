# %%
# import packages
import pandas as pd
import numpy as np
# 1
# load in data
df = pd.read_csv('./heart_failure_clinical_records_dataset.csv', low_memory=False)

df = df.drop('time', axis=1) # removes the time column/variable from the dataframe

print(df.shape) # list dimensions of dataframe(rows=observations, columns=variables)
df.head(10) # shows me first 10 rows of data
# Out:
# (299, 12)
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
# 5  90.0        1                        47         0                 40
# 6  75.0        1                       246         0                 15
# 7  60.0        1                       315         1                 60
# 8  65.0        0                       157         0                 65
# 9  80.0        1                       123         0                 35
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# ...

# %%
df.describe()

# no NA's since count 299 = row/obersvation numer 299
# Out:
#               age     anaemia  creatinine_phosphokinase    diabetes  \
# count  299.000000  299.000000                299.000000  299.000000
# mean    60.833893    0.431438                581.839465    0.418060
# std     11.894809    0.496107                970.287881    0.494067
# min     40.000000    0.000000                 23.000000    0.000000
# 25%     51.000000    0.000000                116.500000    0.000000
# 50%     60.000000    0.000000                250.000000    0.000000
# 75%     70.000000    1.000000                582.000000    1.000000
# max     95.000000    1.000000               7861.000000    1.000000
#
#        ejection_fraction  high_blood_pressure      platelets  \
# count         299.000000           299.000000     299.000000
# mean           38.083612             0.351171  263358.029264
# std            11.834841             0.478136   97804.236869
# min            14.000000             0.000000   25100.000000
# ...

# %%
# 2
df.corr() # make a correlation matrix

# variables strongly associated with a death event:
# age = 0.253729
# serum_creatinine = 0.294278
# ejection_fraction = -0.268603	(negative correlation)
# Out:
#                                age   anaemia  creatinine_phosphokinase  \
# age                       1.000000  0.088006                 -0.081584
# anaemia                   0.088006  1.000000                 -0.190741
# creatinine_phosphokinase -0.081584 -0.190741                  1.000000
# diabetes                 -0.101012 -0.012729                 -0.009639
# ejection_fraction         0.060098  0.031557                 -0.044080
# high_blood_pressure       0.093289  0.038182                 -0.070590
# platelets                -0.052354 -0.043786                  0.024463
# serum_creatinine          0.159187  0.052174                 -0.016408
# serum_sodium             -0.045966  0.041882                  0.059550
# sex                       0.065430 -0.094769                  0.079791
# smoking                   0.018668 -0.107290                  0.002421
# DEATH_EVENT               0.253729  0.066270                  0.062728
#
# ...

# %%
# 3
# For the dummy variables anaemia, diabetes,
# high_blood_pressure, sex, and smoking, compute a summary table of DEATH_EVENT grouped by the variable.
vars = ['anaemia','diabetes','high_blood_pressure','sex','smoking']

for var in vars:
    print(df.loc[:,[var,'DEATH_EVENT']].groupby(var).describe())  # summary table

# For which variables does a higher proportion of the population die when
# the variable takes the value 1 rather than 0?
# looking at mean: amenia & high blood pressure
# diabetes, sex, and smoking all about the same
# Out:
#         DEATH_EVENT
#               count      mean       std  min  25%  50%  75%  max
# anaemia
# 0             170.0  0.294118  0.456991  0.0  0.0  0.0  1.0  1.0
# 1             129.0  0.356589  0.480859  0.0  0.0  0.0  1.0  1.0
#          DEATH_EVENT
#                count      mean       std  min  25%  50%  75%  max
# diabetes
# 0              174.0  0.321839  0.468530  0.0  0.0  0.0  1.0  1.0
# 1              125.0  0.320000  0.468353  0.0  0.0  0.0  1.0  1.0
#                     DEATH_EVENT
#                           count      mean       std  min  25%  50%  75%  max
# high_blood_pressure
# 0                         194.0  0.293814  0.456687  0.0  0.0  0.0  1.0  1.0
# 1                         105.0  0.371429  0.485504  0.0  0.0  0.0  1.0  1.0
#     DEATH_EVENT
#           count      mean       std  min  25%  50%  75%  max
# sex
# 0         105.0  0.323810  0.470173  0.0  0.0  0.0  1.0  1.0
# 1         194.0  0.319588  0.467523  0.0  0.0  0.0  1.0  1.0
#         DEATH_EVENT
# ...

# %%
# 4
# On the basis of your answers from 2 and 3, build a matrix  X  of the variables
# you think are most predictive of a death, and a variable  y  equal to DEATH_EVENT.

# matrix X therefore would contain anemia,  high BP (from Q3) and
# age, serum_creatinine, ejection_fraction (from Q2)

vars = ['anaemia','high_blood_pressure','age','serum_creatinine', 'ejection_fraction']
X = df.loc[:,vars]
y = df['DEATH_EVENT']

# %%
# 5
# Maxmin normalize all of the variables in `X`.
def maxmin(x):
    u = (x-min(x))/(max(x)-min(x))
    return u
X = X.apply(maxmin)

# %%
# 6
# # Split the sample into ~80% for training and ~20% for evaluation.

from sklearn.neighbors import KNeighborsRegressor ## import specific sklearn package
import matplotlib.pyplot as plt ##
from sklearn.model_selection import train_test_split ## import specific sklearn package

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=100) #sets test size .2 = 20 %


# find optimal k
k_bar = 30 ## number of k's to try
k_grid = np.arange(1,k_bar) # considers k's ranging from 1 to k_bar value
SSE = np.zeros(k_bar) ## stores SSE for k_bar to be inputed into this 0 array to be
# filled  with output from function below

for k in range(k_bar):
    fitted_model = KNeighborsRegressor(n_neighbors=k+1).fit(X_train,y_train) # fits model using trianing set
    y_hat = fitted_model.predict(X_test) # predict values for test set
    SSE[k] = np.sum( (y_test-y_hat)**2 ) # saves the computed SSE

SSE_min = np.min(SSE) # Lowest recorded SSE
min_index = np.where(SSE==SSE_min) # Find the indices of y that equal the minimum
k_star = k_grid[min_index] # Find the optimal value of k - since we started the rang at 0,
# we dont need to +1 to this index value
print(k_star) # returns k value with lowest SSE (i.e the optimal k)

plt.plot(np.arange(0,k_bar),SSE) # Plot SSE by k
plt.xlabel("k")
plt.title("optimal k:"+str(k_star)+', SSE:'+str(SSE_min))
plt.ylabel('SSE')
plt.show() # min SSE value on this plot = optimal k
# Out:
# [8]

# %%
# 8
# OK, do steps 5 through 7 again, but use all of the variables (except time)

vars = ['age',	'anaemia',	'creatinine_phosphokinase',	'diabetes',	'ejection_fraction',	'high_blood_pressure',	'platelets',	'serum_creatinine',	'serum_sodium',	'sex',	'smoking']
X = df.loc[:,vars]
y = df['DEATH_EVENT']

# %%
# maxmin normalize all of the variables in `X`.
def maxmin(x):
    u = (x-min(x))/(max(x)-min(x))
    return u
X = X.apply(maxmin)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=100) #sets test size .2 = 20 %


# find optimal k
k_bar = 30 ## number of k's to try
k_grid = np.arange(1,k_bar) # considers k's ranging from 1 to k_bar value
SSE = np.zeros(k_bar) ## stores SSE for k_bar to be inputed into this 0 array to be
# filled  with output from function below

for k in range(k_bar):
    fitted_model = KNeighborsRegressor(n_neighbors=k+1).fit(X_train,y_train) # fits model using trianing set
    y_hat = fitted_model.predict(X_test) # predict values for test set
    SSE[k] = np.sum( (y_test-y_hat)**2 ) # saves the computed SSE

SSE_min = np.min(SSE) # Lowest recorded SSE
min_index = np.where(SSE==SSE_min) # Find the indices of y that equal the minimum
k_star = k_grid[min_index] # Find the optimal value of k - since we started the rang at 0,
# we dont need to +1 to this index value
print(k_star) # returns k value with lowest SSE (i.e the optimal k)

plt.plot(np.arange(0,k_bar),SSE) # Plot SSE by k
plt.xlabel("k")
plt.title("optimal k:"+str(k_star)+', SSE:'+str(SSE_min))
plt.ylabel('SSE')
plt.show() # min SSE value on this plot = optimal k
# Out:
# [19]

# %%
# trying for diff number of variables

# %%
# less vars

vars = ['anaemia',	'high_blood_pressure',	'platelets',	'sex',	'smoking']
X = df.loc[:,vars]
y = df['DEATH_EVENT']

# %%
# maxmin normalize all of the variables in `X`.
def maxmin(x):
    u = (x-min(x))/(max(x)-min(x))
    return u
X = X.apply(maxmin)

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.2,random_state=100) #sets test size .2 = 20 %


# find optimal k
k_bar = 30 ## number of k's to try
k_grid = np.arange(1,k_bar) # considers k's ranging from 1 to k_bar value
SSE = np.zeros(k_bar) ## stores SSE for k_bar to be inputed into this 0 array to be
# filled  with output from function below

for k in range(k_bar):
    fitted_model = KNeighborsRegressor(n_neighbors=k+1).fit(X_train,y_train) # fits model using trianing set
    y_hat = fitted_model.predict(X_test) # predict values for test set
    SSE[k] = np.sum( (y_test-y_hat)**2 ) # saves the computed SSE

SSE_min = np.min(SSE) # Lowest recorded SSE
min_index = np.where(SSE==SSE_min) # Find the indices of y that equal the minimum
k_star = k_grid[min_index] # Find the optimal value of k - since we started the rang at 0,
# we dont need to +1 to this index value
print(k_star) # returns k value with lowest SSE (i.e the optimal k)

plt.plot(np.arange(0,k_bar),SSE) # Plot SSE by k
plt.xlabel("k")
plt.title("optimal k:"+str(k_star)+', SSE:'+str(SSE_min))
plt.ylabel('SSE')
plt.show() # min SSE value on this plot = optimal k
# Out:
# [20]

# %%
# error went up with less variables
